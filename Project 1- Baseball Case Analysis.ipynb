# %% [markdown]
# ### Problem Statement: This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Selection

# %%
df=pd.read_csv ("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df= df.rename(columns = {'W':"Wins", 'R':"Runs", 'AB' : "At_Bats",'H':"Hits",'2B':"Doubles",'3B':"Triples",'HR': "Homeruns",
                          'BB' :"Walks", 'SO': "Strikeouts", 'SB':"Stolen_Bases",'RA' : "Runs_Average", 'ER':"Earned_Runs",
                          'ERA':"Earned_Runs_Avg",'CG':"Complete_Games",'SHO':"Shutouts",'SV':"Saves",'E':"Errors"})
df.head()
# Out:
#    Wins  Runs  At_Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0    95   724     5575  1497      300       42       139    383         973
# 1    83   696     5467  1349      277       44       156    439        1264
# 2    81   669     5439  1395      303       29       141    533        1157
# 3    76   622     5533  1381      260       27       136    404        1231
# 4    74   689     5605  1515      289       49       151    455        1259
#
#    Stolen_Bases  Runs_Average  Earned_Runs  Earned_Runs_Avg  Complete_Games  \
# 0           104           641          601             3.73               2
# 1            70           700          653             4.07               2
# 2            86           640          584             3.67              11
# 3            68           701          643             3.98               7
# 4            83           803          746             4.64               7
#
#    Shutouts  Saves  Errors
# 0         8     56      88
# 1        12     45      86
# 2        10     38      79
# 3         9     37     101
# 4        12     35      86

# %% [markdown]
# ### About Dataset
# Input features:
#
# - Runs: Runs scored
# - At Bats: when a batter reaches base via a fielder's choice, hit or an error (not including catcher's interference) or when a batter is put out on a non-sacrifice.
# - Hits: hits by batters
# - oubles: batter safely reaching second base after hitting the ball
# - Triples: batter safely reaching third base after hitting the ball
# - Homeruns: homeruns by batters
# - Walks: A base on balls, also known as a walk, occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out.
# - Strikeouts: strikeouts by batters
# - Stolen Bases: a stolen base occurs when a runner advances to a base to which he is not entitled and the official scorer rules that the advance should be credited to the action of the runner.
# - Runs Average: runs allowed
# - Earned Runs: Earned runs
# - Earned Run Average (ERA): Earned Runs average
# - Shutouts: act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run.
# - Saves: A save is awarded to the relief pitcher who finishes a game for the winning team, under certain circumstances.
# - Complete Games: act of a pitcher pitching an entire game without the benefit of a relief pitcher.
# - Errors: number of errors committed by each team
#
# - Output: Wins : Number of predicted wins (W)

# %% [markdown]
# ### Data Analysis

# %%
df.shape
# Out:
# (30, 17)

# %%
#Checking Datatypes of features and Null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Wins             30 non-null     int64
#  1   Runs             30 non-null     int64
#  2   At_Bats          30 non-null     int64
#  3   Hits             30 non-null     int64
#  4   Doubles          30 non-null     int64
#  5   Triples          30 non-null     int64
#  6   Homeruns         30 non-null     int64
#  7   Walks            30 non-null     int64
#  8   Strikeouts       30 non-null     int64
#  9   Stolen_Bases     30 non-null     int64
#  10  Runs_Average     30 non-null     int64
#  11  Earned_Runs      30 non-null     int64
#  12  Earned_Runs_Avg  30 non-null     float64
#  13  Complete_Games   30 non-null     int64
#  14  Shutouts         30 non-null     int64
#  15  Saves            30 non-null     int64
#  16  Errors           30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull().sum()
# Out:
# Wins               0
# Runs               0
# At_Bats            0
# Hits               0
# Doubles            0
# Triples            0
# Homeruns           0
# Walks              0
# Strikeouts         0
# Stolen_Bases       0
# Runs_Average       0
# Earned_Runs        0
# Earned_Runs_Avg    0
# Complete_Games     0
# Shutouts           0
# Saves              0
# Errors             0
# dtype: int64

# %% [markdown]
# From above dataset, It is clear that above dataset has no null values.

# %%
#Checking for Duplicated Records or fields
df.duplicated().sum()
# Out:
# 0

# %%
# heatmap to check the missing value
plt.figure(figsize = (7,7))
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#              Wins        Runs      At_Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen_Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# 25%    23.000000  140.250000  428.250000  1157.50000     69.000000
# 50%    31.000000  158.500000  473.000000  1261.50000     83.500000
# 75%    39.000000  177.000000  501.250000  1311.50000     96.500000
# max    49.000000  232.000000  570.000000  1518.00000    134.000000
#
#        Runs_Average  Earned_Runs  Earned_Runs_Avg  Complete_Games   Shutouts  \
# count     30.000000    30.000000        30.000000       30.000000  30.000000
# mean     688.233333   635.833333         3.956333        3.466667  11.300000
# std       72.108005    70.140786         0.454089        2.763473   4.120177
# min      525.000000   478.000000         2.940000        0.000000   4.000000
# 25%      636.250000   587.250000         3.682500        1.000000   9.000000
# 50%      695.500000   644.500000         4.025000        3.000000  12.000000
# 75%      732.500000   679.250000         4.220000        5.750000  13.000000
# max      844.000000   799.000000         5.040000       11.000000  21.000000
#
#            Saves      Errors
# count  30.000000   30.000000
# mean   43.066667   94.333333
# std     7.869335   13.958889
# min    28.000000   75.000000
# 25%    37.250000   86.000000
# 50%    42.000000   91.000000
# 75%    46.750000   96.750000
# max    62.000000  126.000000

# %%
#visualizing statistical description of dataset
plt.figure(figsize = (15,10))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth = 2,annot= True, fmt = "f")
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.title("Satistical Report of Numerical Variables")
plt.show()

# %% [markdown]
# - Wins
#     - mean: 80.9666
#     - std: 10.4534
#     - min: 63
#     - max: 100
#
# - Runs
#     - mean: 688.2333
#     - std: 58.7617
#     - min: 573
#     - max: 891
#
# - At_bats
#     - mean: 5516.2666
#     - std: 70.4673
#     - min: 5835
#     - max: 5649
#
# - Hits
#     - mean: 57.1409
#     - std: 57.1409
#     - min: 1324
#     - max: 1515
#
# - Doubles
#     - mean: 274.7333
#     - std: 18.0954
#     - min: 236
#     - max: 308
#
# - Triples
#     - mean: 31.30
#     - std: 10.4523
#     - min: 13
#     - max: 49
#
# - HomeRuns
#     - mean: 163.6333
#     - std: 31.8233
#     - min: 100
#     - max: 232
#
# - Walks
#     - mean: 469.1
#     - std: 57.053
#     - min: 375
#     - max: 570
#
# - StrikeOuts
#     - mean: 1248.2
#     - std: 103.7594
#     - min: 973
#     - max: 1518
#
# - Stolen_Bases
#     - mean: 83.50
#     - std: 22.8152
#     - min: 44
#     - max: 134
#
# - RunsAverage
#     - mean: 688.2333
#     - std: 72.108
#     - min: 525
#     - max: 844
#
# - Earned_Runs
#     - mean: 635.8333
#     - std: 70.1407
#     - min: 478
#     - max: 799
#
# - Earned_Runs_Avg
#     - mean: 3.9563
#     - std: 0.4540
#     - min: 2.94
#     - max: 5.04
#
# - Complete_Games
#     - mean: 3.4666
#     - std: 2.7634
#     - min: 0
#     - max: 11
#
# - Shutouts
#     - mean: 11.3
#     - std: 4.1201
#     - min: 4
#     - max: 21
#
# - Saves
#     - mean: 43.0666
#     - std: 7.8693
#     - min: 28
#     - max: 62
#
# - Errors
#     - mean: 94.3333
#     - std: 13.9588
#     - min: 75
#     - max: 126

# %%
#Getting correlation matrix
correlation = df.corr()

# %%
#Multivariate Analysis
#Checking Correlation among features
plt.figure(figsize = (20,12))
sns.heatmap(round(correlation,3), annot = True, linewidth = .2 , fmt = '1')
plt.show()

# %% [markdown]
# - Runs_Average, Earned_Runs and Earned_Runs_Avg have high negative correlation with Wins.
# - At_Bats have high positive correlation with Hits.
# - HomeRuns and Runs have high positive correlation.
# - Saves and Wins have high positive correlation.
# - Saves and Runs_average, Earned_Runs_Average have moderately high positive correlation.
# - Shutouts have moderatey high positive correlation with Runs_Average, Earned_Runs and Earned_Runs_Avg.

# %%
df['Wins'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: Wins, dtype: int64

# %%
#Storing target values in the variable data
data = df['Wins'].value_counts()

# %%
#Let's visulaized target parameter.
plt.figure(figsize=(15, 10))
sns.barplot(x=data.index, y=data.values, alpha=0.6)
plt.xlabel("Number of wins", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.title("Wins parameters", fontsize=16)
plt.show()

# %% [markdown]
# Bar Plot helps to visualized all parameters better. Above graphs showing Number of wins parameters (X-Axis) and there number of data points count (Y-Axis). Now visualized every parameter (features) with quality (Label) parameter with help of scatter plot.

# %%
sns.scatterplot(x='Runs',y='Wins',data=df)
# Out:
# <Axes: xlabel='Runs', ylabel='Wins'>

# %%
sns.scatterplot(x='At_Bats',y='Wins',data=df)
# Out:
# <Axes: xlabel='At_Bats', ylabel='Wins'>

# %%
sns.scatterplot(x='Hits',y='Wins',data=df)
# Out:
# <Axes: xlabel='Hits', ylabel='Wins'>

# %%
sns.scatterplot(x='Doubles',y='Wins',data=df)
# Out:
# <Axes: xlabel='Doubles', ylabel='Wins'>

# %%
sns.scatterplot(x='Triples',y='Wins',data=df)
# Out:
# <Axes: xlabel='Triples', ylabel='Wins'>

# %%
sns.scatterplot(x='Homeruns',y='Wins',data=df)
# Out:
# <Axes: xlabel='Homeruns', ylabel='Wins'>

# %%
sns.scatterplot(x='Walks',y='Wins',data=df)
# Out:
# <Axes: xlabel='Walks', ylabel='Wins'>

# %%
sns.scatterplot(x='Strikeouts',y='Wins',data=df)
# Out:
# <Axes: xlabel='Strikeouts', ylabel='Wins'>

# %%
sns.scatterplot(x='Stolen_Bases',y='Wins',data=df)
# Out:
# <Axes: xlabel='Stolen_Bases', ylabel='Wins'>

# %%
sns.scatterplot(x='Runs_Average',y='Wins',data=df)
# Out:
# <Axes: xlabel='Runs_Average', ylabel='Wins'>

# %%
sns.scatterplot(x='Earned_Runs',y='Wins',data=df)
# Out:
# <Axes: xlabel='Earned_Runs', ylabel='Wins'>

# %%
sns.scatterplot(x='Earned_Runs_Avg',y='Wins',data=df)
# Out:
# <Axes: xlabel='Earned_Runs_Avg', ylabel='Wins'>

# %%
sns.scatterplot(x='Complete_Games',y='Wins',data=df)
# Out:
# <Axes: xlabel='Complete_Games', ylabel='Wins'>

# %%
sns.scatterplot(x='Shutouts',y='Wins',data=df)
# Out:
# <Axes: xlabel='Shutouts', ylabel='Wins'>

# %%
sns.scatterplot(x='Saves',y='Wins',data=df)
# Out:
# <Axes: xlabel='Saves', ylabel='Wins'>

# %%
sns.scatterplot(x='Errors',y='Wins',data=df)
# Out:
# <Axes: xlabel='Errors', ylabel='Wins'>

# %%
#Checking all graphs using pairplot method
sns.pairplot(df)
plt.show()

# %%
df.plot(kind='box',subplots=True,figsize=(15,10))
# Out:
# Wins                  Axes(0.125,0.11;0.0383663x0.77)
# Runs                Axes(0.17104,0.11;0.0383663x0.77)
# At_Bats            Axes(0.217079,0.11;0.0383663x0.77)
# Hits               Axes(0.263119,0.11;0.0383663x0.77)
# Doubles            Axes(0.309158,0.11;0.0383663x0.77)
# Triples            Axes(0.355198,0.11;0.0383663x0.77)
# Homeruns           Axes(0.401238,0.11;0.0383663x0.77)
# Walks              Axes(0.447277,0.11;0.0383663x0.77)
# Strikeouts         Axes(0.493317,0.11;0.0383663x0.77)
# Stolen_Bases       Axes(0.539356,0.11;0.0383663x0.77)
# Runs_Average       Axes(0.585396,0.11;0.0383663x0.77)
# Earned_Runs        Axes(0.631436,0.11;0.0383663x0.77)
# Earned_Runs_Avg    Axes(0.677475,0.11;0.0383663x0.77)
# Complete_Games     Axes(0.723515,0.11;0.0383663x0.77)
# Shutouts           Axes(0.769554,0.11;0.0383663x0.77)
# Saves              Axes(0.815594,0.11;0.0383663x0.77)
# Errors             Axes(0.861634,0.11;0.0383663x0.77)
# dtype: object

# %% [markdown]
# This Chart shows outliers are present in data we will remove outliers in data cleaning part

# %%
#Visualising Data distribution of our dataset
for i in df.columns:
    sns.distplot(df[i])
    plt.subplot(111)
    plt.show()

# %% [markdown]
# In above input parameters we are checking if there are any outliers in the input data using the distplot method

# %%
#statistical summary
df.describe()
# Out:
#              Wins        Runs      At_Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen_Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# 25%    23.000000  140.250000  428.250000  1157.50000     69.000000
# 50%    31.000000  158.500000  473.000000  1261.50000     83.500000
# 75%    39.000000  177.000000  501.250000  1311.50000     96.500000
# max    49.000000  232.000000  570.000000  1518.00000    134.000000
#
#        Runs_Average  Earned_Runs  Earned_Runs_Avg  Complete_Games   Shutouts  \
# count     30.000000    30.000000        30.000000       30.000000  30.000000
# mean     688.233333   635.833333         3.956333        3.466667  11.300000
# std       72.108005    70.140786         0.454089        2.763473   4.120177
# min      525.000000   478.000000         2.940000        0.000000   4.000000
# 25%      636.250000   587.250000         3.682500        1.000000   9.000000
# 50%      695.500000   644.500000         4.025000        3.000000  12.000000
# 75%      732.500000   679.250000         4.220000        5.750000  13.000000
# max      844.000000   799.000000         5.040000       11.000000  21.000000
#
#            Saves      Errors
# count  30.000000   30.000000
# mean   43.066667   94.333333
# std     7.869335   13.958889
# min    28.000000   75.000000
# 25%    37.250000   86.000000
# 50%    42.000000   91.000000
# 75%    46.750000   96.750000
# max    62.000000  126.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def valcal():
    vif=pd.DataFrame()
    vif['vif factor']=[variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
    vif['features']=df.columns
    print(vif)

# %%
valcal()
# Out:
#       vif factor         features
# 0    1164.543214             Wins
# 1    3253.807721             Runs
# 2    5181.779465          At_Bats
# 3    4817.334228             Hits
# 4    1157.105781          Doubles
# 5      32.435486          Triples
# 6     309.301103         Homeruns
# 7     302.099558            Walks
# 8     400.292880       Strikeouts
# 9      28.665516     Stolen_Bases
# 10  18170.014649     Runs_Average
# 11  51175.790270      Earned_Runs
# 12  23668.747242  Earned_Runs_Avg
# 13     10.411616   Complete_Games
# 14     33.258426         Shutouts
# 15    331.282416            Saves
# 16     96.958680           Errors

# %% [markdown]
# ## Data Cleaning

# %%
#Checking for skewness in our Dataset
df.skew()
# Out:
# Wins               0.047089
# Runs               1.200786
# At_Bats            0.183437
# Hits               0.670254
# Doubles           -0.230650
# Triples            0.129502
# Homeruns           0.516441
# Walks              0.158498
# Strikeouts        -0.156065
# Stolen_Bases       0.479893
# Runs_Average       0.045734
# Earned_Runs        0.058710
# Earned_Runs_Avg    0.053331
# Complete_Games     0.736845
# Shutouts           0.565790
# Saves              0.657524
# Errors             0.890132
# dtype: float64

# %% [markdown]
# Following columns seems to have skewness
# - Runs              = 1.200786
# - Complete_Games    = 0.736845
# - Saves             = 0.657524
# - Errors            = 0.890132

# %%
#Removing skewness using log transformation
df['Runs'] = np.log(df['Runs'])
df['Runs'].skew()
# Out:
# 0.7441956366104983

# %%
#Visualising data distribution after skewness removal
fig, ax = plt.subplots(1,2,figsize = (8,4))
sns.boxplot(df['Runs'], ax = ax[0])
sns.distplot(df['Runs'],color = 'green', ax = ax[1])
# Out:
# <Axes: xlabel='Runs', ylabel='Density'>

# %%
#Removing skewness using log transformation
df['Errors'] = np.log(df['Errors'])
df['Errors'].skew()
# Out:
# 0.6300804690891397

# %%
#Visualising data distribution after skewness removal
fig, ax = plt.subplots(1,2,figsize = (8,4))
sns.boxplot(df['Errors'], ax = ax[0])
sns.distplot(df['Errors'],color = 'green', ax = ax[1])
# Out:
# <Axes: xlabel='Errors', ylabel='Density'>

# %%
#Removing skewness using square-root transformation
df['Complete_Games'] = np.sqrt(df['Complete_Games'])
df['Complete_Games'].skew()
# Out:
# -0.3114761683268212

# %%
#Visualising data distribution after skewness removal
fig, ax = plt.subplots(1,2,figsize = (8,4))
sns.boxplot(df['Complete_Games'], ax = ax[0])
sns.distplot(df['Complete_Games'],color = 'green', ax = ax[1])
# Out:
# <Axes: xlabel='Complete_Games', ylabel='Density'>

# %%
#Removing skewness using log transformation
df['Saves'] = np.log(df['Saves'])
df['Saves'].skew()
# Out:
# 0.15058249970623516

# %%
#Visualising data distribution after skewness removal
fig, ax = plt.subplots(1,2,figsize = (8,4))
sns.boxplot(df['Saves'], ax = ax[0])
sns.distplot(df['Saves'],color = 'green', ax = ax[1])
# Out:
# <Axes: xlabel='Saves', ylabel='Density'>

# %% [markdown]
# ## Model Building

# %%
#Splitting Dataset into predictors and target
X = df.drop(columns = 'Wins', axis = 1)
y = df['Wins']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# %%
#Sclain our independent variable
Scaler = StandardScaler()
X_Scaled = Scaler.fit_transform(X)

# %%
#Splitting Dataset into training and testing set
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25)

# %% [markdown]
# ## Linear Regression Model

# %%
#Importing Predictive Models 
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import statsmodels.formula.api as smf
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from scipy.stats import uniform
from sklearn.model_selection import RandomizedSearchCV

#Importing model evaluation metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import cross_val_score

#Importing Lasso and Ridge for Regularization
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV

# %%
#Model instantiating and fitting
lm = LinearRegression()

lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Printing model confidence on training set and testing set
print("Linear Regression Model Confidence on training set : ",round(lm.score(X_train,y_train)*100,2),'%')
print("Linear Regression Model Confidence on testing set : ",round(lm.score(X_test,y_test)*100,2),'%')
# Out:
# Linear Regression Model Confidence on training set :  96.06 %
# Linear Regression Model Confidence on testing set :  76.14 %

# %%
#Performing Model Predictions on X_test
y_pred = lm.predict(X_test)

# %%
#printing Intercept and weights our Linear Regression Model
print("Intercept for Linear Regression Model is : ",lm.intercept_,'\n')
weights = zip(X.columns,lm.coef_)
weights = pd.DataFrame(list(weights), columns = ['features', 'coefficients'])
print("Features and their corresponding weights:")
weights
# Out:
# Intercept for Linear Regression Model is :  -132.24743548177352
#
# Features and their corresponding weights:
#            features  coefficients
# 0              Runs     88.498144
# 1           At_Bats     -0.062809
# 2              Hits      0.034922
# 3           Doubles     -0.044786
# 4           Triples     -0.099269
# 5          Homeruns     -0.019594
# 6             Walks     -0.042473
# 7        Strikeouts     -0.015102
# 8      Stolen_Bases     -0.025227
# 9      Runs_Average      0.089135
# 10      Earned_Runs      0.533128
# 11  Earned_Runs_Avg   -110.017025
# 12   Complete_Games      0.751091
# 13         Shutouts      0.139974
# 14            Saves     13.727319
# 15           Errors     -6.145386

# %%
#Applying Evaluation metrics to our Regression model
print('R squared for our Linear Regression Model:', r2_score(y_test,y_pred))
print('Mean Absolute Error for our Linear Regression Model:',mean_absolute_error(y_test,y_pred))
print('Mean Squared Error for our Linear Regression Model:',mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error for our Linear Regression Model:',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R squared for our Linear Regression Model: 0.7614006505006612
# Mean Absolute Error for our Linear Regression Model: 5.580009405906967
# Mean Squared Error for our Linear Regression Model: 43.36543177150483
# Root Mean Squared Error for our Linear Regression Model: 6.585243486121438

# %%
plt.figure(figsize = (10,10))
sns.regplot(x=y_test,y=y_pred,data=X_Scaled, color = 'green')
plt.xlabel('Actual Wins')
plt.ylabel('Predicted Wins')
plt.title('Actual Wins vs Predicted Wins')
plt.show()

# %%
#Performing OLS model on all 

OLS = smf.ols(formula = 'y~ X',data = df).fit()
OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     15.91
# Date:                Sun, 03 Mar 2024   Prob (F-statistic):           5.25e-06
# Time:                        19:00:11   Log-Likelihood:                -67.098
# No. Observations:                  30   AIC:                             168.2
# Df Residuals:                      13   BIC:                             192.0
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -326.7557    194.985     -1.676      0.118    -747.995      94.483
# X[0]          83.3948     25.578      3.260      0.006      28.138     138.652
# X[1]          -0.0334      0.032     -1.039      0.318      -0.103       0.036
# X[2]           0.0244      0.032      0.752      0.465      -0.046       0.094
# X[3]          -0.1095      0.071     -1.545      0.146      -0.263       0.044
# X[4]           0.0363      0.113      0.321      0.753      -0.208       0.281
# X[5]          -0.0438      0.065     -0.672      0.513      -0.185       0.097
# X[6]          -0.0242      0.022     -1.093      0.294      -0.072       0.024
# X[7]          -0.0015      0.010     -0.151      0.882      -0.024       0.021
# X[8]          -0.0201      0.039     -0.509      0.620      -0.105       0.065
# X[9]           0.1011      0.124      0.817      0.429      -0.166       0.369
# X[10]          0.1705      0.382      0.447      0.662      -0.654       0.995
# X[11]        -55.4881     49.822     -1.114      0.286    -163.123      52.147
# X[12]          2.1312      1.238      1.722      0.109      -0.543       4.805
# X[13]          0.2285      0.294      0.777      0.451      -0.407       0.864
# X[14]         25.6117      7.689      3.331      0.005       9.000      42.223
# X[15]          0.7503      6.585      0.114      0.911     -13.475      14.976
# ==============================================================================
# Omnibus:                        3.384   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.184   Jarque-Bera (JB):                2.792
# Skew:                          -0.742   Prob(JB):                        0.248
# Kurtosis:                       2.818   Cond. No.                     1.87e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.87e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Performing Feature Selection to achieve better performance

# %%
#pearson's correlation feature selection for numeric input and numeric output

# define feature selection
fs = SelectKBest(score_func=f_regression, k=11)
# apply feature selection
X_selected = fs.fit_transform(X_Scaled, y)

df_scores = pd.DataFrame(fs.scores_)
df_columns = pd.DataFrame(X.columns)

#concatenate dataframes
feature_scores = pd.concat([df_columns,df_scores], axis=1)
feature_scores.columns = ['Feature_Name', 'Score']

#Sorting in Descending order
print(feature_scores.nlargest(11,'Score'))
# Out:
#        Feature_Name      Score
# 11  Earned_Runs_Avg  57.299198
# 9      Runs_Average  54.569271
# 10      Earned_Runs  53.202874
# 14            Saves  22.557243
# 6             Walks   8.581552
# 13         Shutouts   8.017499
# 0              Runs   6.829909
# 3           Doubles   6.272152
# 5          Homeruns   2.922118
# 4           Triples   1.884521
# 8      Stolen_Bases   0.709779

# %%
X_train,X_test,y_train,y_test= train_test_split(X_selected,y,test_size = 0.2)

# %%
lm.fit(X_train,y_train)
lm.score(X_test,y_test)
# Out:
# 0.8855080468411247

# %%
y_pred = lm.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8855080468411247

# %%
#Printing model confidence on training set and testing set
print("Linear Regression Model Confidence on training set : ",round(lm.score(X_train,y_train)*100,2),'%')
print("Linear Regression Model Confidence on testing set : ",round(lm.score(X_test,y_test)*100,2),'%')
# Out:
# Linear Regression Model Confidence on training set :  93.01 %
# Linear Regression Model Confidence on testing set :  88.55 %

# %%
#Applying Evaluation metrics to our Regression model
print('R squared for our Linear Regression Model:', r2_score(y_test,y_pred))
print('Mean Absolute Error for our Linear Regression Model:',mean_absolute_error(y_test,y_pred))
print('Mean Squared Error for our Linear Regression Model:',mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error for our Linear Regression Model:',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R squared for our Linear Regression Model: 0.8855080468411247
# Mean Absolute Error for our Linear Regression Model: 2.897420528715948
# Mean Squared Error for our Linear Regression Model: 11.525523284660109
# Root Mean Squared Error for our Linear Regression Model: 3.3949261088660103

# %%
plt.figure(figsize = (10,10))
sns.regplot(x=y_test,y=y_pred,data=X_Scaled, color = 'orange')
plt.xlabel('Actual WinRate')
plt.ylabel('Predicted WinRate')
plt.title('Actual WinRate vs Predicted WinRate')
plt.show()

# %% [markdown]
# ## Regularization using Ridge

# %%
from sklearn.linear_model import RidgeCV

# Normalize the features
scaler = StandardScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# %%
#Ridge will return best alpha and coefficients after performing 10 cross validations
ridgecv = RidgeCV(alphas=np.arange(0.001, 0.2, 0.001))
ridgecv.fit(X_train_normalized, y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009,
#        0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017, 0.018,
#        0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026, 0.027,
#        0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035, 0.036,
#        0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044, 0.045,
#        0.046, 0.047, 0.048, 0.049, 0.05 , 0.051, 0.052, 0.053, 0.054,
#        0.055, 0.0...
#        0.136, 0.137, 0.138, 0.139, 0.14 , 0.141, 0.142, 0.143, 0.144,
#        0.145, 0.146, 0.147, 0.148, 0.149, 0.15 , 0.151, 0.152, 0.153,
#        0.154, 0.155, 0.156, 0.157, 0.158, 0.159, 0.16 , 0.161, 0.162,
#        0.163, 0.164, 0.165, 0.166, 0.167, 0.168, 0.169, 0.17 , 0.171,
#        0.172, 0.173, 0.174, 0.175, 0.176, 0.177, 0.178, 0.179, 0.18 ,
#        0.181, 0.182, 0.183, 0.184, 0.185, 0.186, 0.187, 0.188, 0.189,
#        0.19 , 0.191, 0.192, 0.193, 0.194, 0.195, 0.196, 0.197, 0.198,
#        0.199]))

# %%
ridgecv.alpha_
# Out:
# 0.199

# %%
ridge_model = Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.199)

# %%
ridge_model.score(X_test,y_test)
# Out:
# 0.8879097131167534

# %%
ridgepred = ridge_model.predict(X_test)

# %%
#Applying Evaluation metrics to our Tuned Lasso Regression model
print('R2 Score for Tuned Ridge Regression Model:', r2_score(y_test,ridgepred))
print('Mean Absolute Error for our Tuned Ridge Regression Model:',mean_absolute_error(y_test,ridgepred))
print('Mean Squared Error for our Tuned Ridge Regression Model:',mean_squared_error(y_test,ridgepred))
print('Root Mean Squared Error for our Ridge Linear Regression Model:',np.sqrt(mean_squared_error(y_test,ridgepred)))
# Out:
# R2 Score for Tuned Ridge Regression Model: 0.8879097131167534
# Mean Absolute Error for our Tuned Ridge Regression Model: 3.1002324206920755
# Mean Squared Error for our Tuned Ridge Regression Model: 11.283755546246823
# Root Mean Squared Error for our Ridge Linear Regression Model: 3.359130177031968

# %%
#Plotting Regression Line
plt.figure(figsize = (10,10))
sns.regplot(x=y_test,y=ridgepred,data=X, color = 'purple')
plt.xlabel('Actual WinRate')
plt.ylabel('Predicted WinRate')
plt.title('Actual WinRate vs Predicted WinRate')
plt.show()

# %% [markdown]
# ## Regularization using Lasso

# %%
from sklearn.linear_model import LassoCV
#LassoCV(lasso cross validation) will return the best alpha after max iterations
#normalizing is subtracting the mean and dividing by l2-norm
scaler = StandardScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

lasscv = LassoCV(alphas=None, max_iter=2000)
lasscv.fit(X_train_normalized, y_train)
alpha = lasscv.alpha_

# %%
#Now that we have best parameter, let's use lasso regression and see how well our data has fitted before
alpha = lasscv.alpha_

lasso_reg = Lasso(alpha)
lasso_reg.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.022066666951550528)

# %%
#Model Confidence After using Lasso Regression
print('Model Confidence After using Lasso Regularization Model: ',round(lasso_reg.score(X_test,y_test),3)*100, '%')
# Out:
# Model Confidence After using Lasso Regularization Model:  88.8 %

# %%
lassopred = lasso_reg.predict(X_test)

# %%
#Applying Evaluation metrics to our Tuned Lasso Regression model
print('R2 Score for Tuned Lasso Regression Model:', r2_score(y_test,lassopred))
print('Mean Absolute Error for our Tuned Lasso Regression Model:',mean_absolute_error(y_test,lassopred))
print('Mean Squared Error for our Tuned Lasso Regression Model:',mean_squared_error(y_test,lassopred))
print('Root Mean Squared Error for our Lasso Linear Regression Model:',np.sqrt(mean_squared_error(y_test,lassopred)))
# Out:
# R2 Score for Tuned Lasso Regression Model: 0.8876909715397395
# Mean Absolute Error for our Tuned Lasso Regression Model: 3.059214369732461
# Mean Squared Error for our Tuned Lasso Regression Model: 11.305775531666216
# Root Mean Squared Error for our Lasso Linear Regression Model: 3.362406211579174

# %%
plt.figure(figsize = (10,10))
sns.regplot(x=y_test,y=lassopred,data=X_selected, color = 'blue')
plt.xlabel('Actual WinRate')
plt.ylabel('Predicted WinRate')
plt.title('Actual WinRate vs Predicted WinRate')
plt.show()

# %% [markdown]
# ## Decision Tree Regressor

# %%
#Instantiating model
dt = DecisionTreeRegressor()

# %%
#Fitting model
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
#predicting X_test
y_pred = dt.predict(X_test)

# %%
#Applying Evaluation metrics to our Decision Tree Regressor model
print('R2 Score for Decision Tree Regressor:', r2_score(y_test,y_pred))
print('Mean Absolute Error for our Decision Tree Regressor Model:',mean_absolute_error(y_test,y_pred))
print('Mean Squared Error for our Decision Tree Regressor Model:',mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error for our Decision Tree Regressor Model:',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score for Decision Tree Regressor: -0.036423841059602724
# Mean Absolute Error for our Decision Tree Regressor Model: 10.0
# Mean Squared Error for our Decision Tree Regressor Model: 104.33333333333333
# Root Mean Squared Error for our Decision Tree Regressor Model: 10.214368964029708

# %%
plt.figure(figsize = (10,10))
sns.regplot(x=y_test,y=y_pred,data=X, color = 'grey')
plt.xlabel('Actual WinRate')
plt.ylabel('Predicted WinRate')
plt.title('Actual WinRate vs Predicted WinRate')
plt.show()

# %% [markdown]
# ## K Nearest Neighbor

# %%
#Model Instantiating
knn = KNeighborsRegressor(n_neighbors = 9)

# %%
#Model Fitting
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=9)

# %%
knnpred  = knn.predict(X_test)

# %%
#Applying Evaluation metrics to our KNN Regression model
print('R2 Score for KNN Regression Model:', r2_score(y_test,knnpred))
print('Mean Absolute Error for our KNN Regression Model:',mean_absolute_error(y_test,knnpred))
print('Mean Squared Error for our KNN Regression Model:',mean_squared_error(y_test,knnpred))
print('Root Mean Squared Error for our KNN Regression Model:',np.sqrt(mean_squared_error(y_test,knnpred)))
# Out:
# R2 Score for KNN Regression Model: 0.6107636333905649
# Mean Absolute Error for our KNN Regression Model: 4.092592592592593
# Mean Squared Error for our KNN Regression Model: 39.18312757201647
# Root Mean Squared Error for our KNN Regression Model: 6.259642767124691

# %%
plt.figure(figsize = (10,10))
sns.regplot(x=y_test,y=knnpred,data=X, color = 'grey')
plt.xlabel('Actual WinRate')
plt.ylabel('Predicted WinRate')
plt.title('Actual WinRate vs Predicted WinRate')
plt.show()

# %% [markdown]
# ## Boosting using Gradient Boosting Regressor

# %%
gradient = GradientBoostingRegressor()

# %%
gradient.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
grpred = gradient.predict(X_test)

# %%
#Applying Evaluation metrics to our Gradient Boostin Regresser model
print('R2 Score for Gradient Boostin Regresser Model:', r2_score(y_test,grpred))
print('Mean Absolute Error for our Gradient Boostin Regresser Model:',mean_absolute_error(y_test,grpred))
print('Mean Squared Error for our Gradient Boostin Regresser Model:',mean_squared_error(y_test,grpred))
print('Root Mean Squared Error for our Gradient Boostin Regresser Model:',np.sqrt(mean_squared_error(y_test,grpred)))
# Out:
# R2 Score for Gradient Boostin Regresser Model: 0.6107080241708946
# Mean Absolute Error for our Gradient Boostin Regresser Model: 4.47648629750761
# Mean Squared Error for our Gradient Boostin Regresser Model: 39.1887255667966
# Root Mean Squared Error for our Gradient Boostin Regresser Model: 6.260089900855785

# %% [markdown]
# ## Random Forest Regressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfpred = rf.predict(X_test)

# %%
#Applying Evaluation metrics to our KNN Regression model
print('R2 Score for Random Forest Regressor Model:', r2_score(y_test,rfpred))
print('Mean Absolute Error for our KNN Regression Model:',mean_absolute_error(y_test,rfpred))
print('Mean Squared Error for our KNN Regression Model:',mean_squared_error(y_test,rfpred))
print('Root Mean Squared Error for our KNN Regression Model:',np.sqrt(mean_squared_error(y_test,rfpred)))
# Out:
# R2 Score for Random Forest Regressor Model: 0.5764806291390726
# Mean Absolute Error for our KNN Regression Model: 5.711666666666669
# Mean Squared Error for our KNN Regression Model: 42.63428333333336
# Root Mean Squared Error for our KNN Regression Model: 6.529493344305771

# %% [markdown]
# ## Hyper Parameter Tuning of Best Model

# %%
#Using Randomized Search
param_grid = {'alpha': uniform()}

model = Lasso()
rand_search = RandomizedSearchCV(estimator=model, 
                            param_distributions=param_grid,
                                 n_iter=100)

rand_search.fit(X_train,y_train)

print(rand_search.best_estimator_.alpha)
print(rand_search.best_score_)
# Out:
# 0.021456405709921467
# 0.7447140275340176

# %%
pred = rand_search.predict(X_test)

# %%
#Applying Evaluation metrics to our Tuned Lasso Regression model
print('R2 Score for Tuned Lasso Regression Model:', r2_score(y_test,pred))
print('Mean Absolute Error for our Tuned Lasso Regression Model:',mean_absolute_error(y_test,pred))
print('Mean Squared Error for our Tuned Lasso Regression Model:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error for our Lasso Linear Regression Model:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 Score for Tuned Lasso Regression Model: 0.8877599763555509
# Mean Absolute Error for our Tuned Lasso Regression Model: 3.0571105256403874
# Mean Squared Error for our Tuned Lasso Regression Model: 11.298829046874543
# Root Mean Squared Error for our Lasso Linear Regression Model: 3.3613730895088905

# %%
plt.figure(figsize = (10,10))
sns.regplot(x=y_test,y=pred,data=X, color = 'purple')
plt.xlabel('Actual WinRate')
plt.ylabel('Predicted WinRate')
plt.title('Actual WinRate vs Predicted WinRateWinRate')
plt.show()

# %% [markdown]
# ## Saving Final Model

# %%
import joblib
joblib.dump(lasso_reg,"BaseBall_Case_Prediction.pkl")
# Out:
# ['BaseBall_Case_Prediction.pkl']

# %% [markdown]
# ## Loading our Saved model

# %%
model = joblib.load("BaseBall_Case_Prediction.pkl")

# %%
#predicting test data using loaded model
prediction = model.predict(X_test)
prediction
# Out:
# array([82.26460562, 82.87951258, 83.51222844, 96.16750768, 92.45597078,
#        69.67758195])

# %%
#Analysing Predicted vs Actual
results = pd.DataFrame()
results['Predicted'] = prediction
results['Actual'] = y
results
# Out:
#    Predicted  Actual
# 0  82.264606      95
# 1  82.879513      83
# 2  83.512228      81
# 3  96.167508      76
# 4  92.455971      74
# 5  69.677582      93

# %%
#Converting the saved file into .csv format
results.to_csv('Results.csv',index = True)
